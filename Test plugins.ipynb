# %%
import pandas as pd
from random import random

df = pd.DataFrame([
    random() for i in range(1000)
])

def import_plugin(plugin_name):
    module = __import__(plugin_name)
    if getattr(module, 'filter', None):
        print('Activate plugin %s' % plugin_name)
        return module.filter
    else:
        message = 'Plugin %s does not have filter' % plugin_name
        print(dir(module))
        print(module.__cached__)
        raise Exception(message)
    
def get_plugins():
    with open('plugins.cfg') as f:
        modules = [line.strip() for line in f.readlines()]
        return map(import_plugin, modules)

for plugin in get_plugins():
    df = plugin(df)

df
# Out:
# Activate plugin rolling_mean
# Activate plugin plus_100
#               0
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# 5           NaN
# 6           NaN
# 7           NaN
# 8           NaN
# 9    100.522013
# 10   100.501703
# 11   100.477449
# 12   100.432081
# 13   100.425991
# 14   100.464654
# 15   100.379379
# 16   100.382254
# 17   100.401097
# 18   100.386633
# 19   100.383375
# 20   100.442839
# 21   100.404951
# 22   100.432106
# 23   100.441927
# 24   100.386600
# 25   100.438141
# 26   100.424876
# 27   100.417725
# 28   100.366021
# 29   100.413525
# ..          ...
# 970  100.474951
# 971  100.528671
# 972  100.515204
# 973  100.473419
# 974  100.468953
# 975  100.387712
# 976  100.366238
# 977  100.363575
# 978  100.431731
# 979  100.463230
# 980  100.479932
# 981  100.507986
# 982  100.481684
# 983  100.538788
# 984  100.626312
# 985  100.634221
# 986  100.716810
# 987  100.709804
# 988  100.648166
# 989  100.677033
# ...
